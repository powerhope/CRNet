# %%
import matplotlib
matplotlib.use('Agg')
import scipy
from scipy import ndimage
import torch, cv2
import numpy as np
import numpy.ma as ma
import sys
import pdb
import torch

from torch.autograd import Variable
import torchvision.models as models
import torch.nn.functional as F
from torch.utils import data
# from dataset import get_segmentation_dataset
# from network import get_segmentation_model
# from config import Parameters
from collections import OrderedDict
import os
import scipy.ndimage as nd
from math import ceil
from PIL import Image as PILImage

import matplotlib.pyplot as plt
import torch.nn as nn

# %%
def get_palette(num_cls):
    """ Returns the color map for visualizing the segmentation mask.
    Args:
        num_cls: Number of classes
    Returns:
        The color map
    """

    palette = [0] * (num_cls * 3)
    palette[0:3] = (128, 64, 128)       # 0: 'road' 
    palette[3:6] = (244, 35,232)        # 1 'sidewalk'
    palette[6:9] = (70, 70, 70)         # 2''building'
    palette[9:12] = (102,102,156)       # 3 wall
    palette[12:15] =  (190,153,153)     # 4 fence
    palette[15:18] = (153,153,153)      # 5 pole
    palette[18:21] = (250,170, 30)      # 6 'traffic light'
    palette[21:24] = (220,220, 0)       # 7 'traffic sign'
    palette[24:27] = (107,142, 35)      # 8 'vegetation'
    palette[27:30] = (152,251,152)      # 9 'terrain'
    palette[30:33] = ( 70,130,180)      # 10 sky
    palette[33:36] = (220, 20, 60)      # 11 person
    palette[36:39] = (255, 0, 0)        # 12 rider
    palette[39:42] = (0, 0, 142)        # 13 car
    palette[42:45] = (0, 0, 70)         # 14 truck
    palette[45:48] = (0, 60,100)        # 15 bus
    palette[48:51] = (0, 80,100)        # 16 train
    palette[51:54] = (0, 0,230)         # 17 'motorcycle'
    palette[54:57] = (119, 11, 32)      # 18 'bicycle'
    palette[57:60] = (105, 105, 105)
    return palette

def pad_image(img, target_size):
    """Pad an image up to the target size."""
    rows_missing = target_size[0] - img.shape[2]
    cols_missing = target_size[1] - img.shape[3]
    padded_img = np.pad(img, ((0, 0), (0, 0), (0, rows_missing), (0, cols_missing)), 'constant')
    return padded_img
def predict_whole_img_w_label(net, image, classes, method, scale, label):
    """
         Predict the whole image w/o using multiple crops.
         The scale specify whether rescale the input image before predicting the results.
    """
#     N_, C_, H_, W_ = image.shape
#     if torch_ver == '0.4':
#         interp = nn.Upsample(size=(H_, W_), mode='bilinear', align_corners=True)
#     else:
#     interp = nn.Upsample(size=(H_, W_), mode='bilinear')

#     bug
#     if scale > 1:
#         scaled_img = ndimage.zoom(image, (1.0, 1.0, scale, scale), order=1, prefilter=False)
#     else:
#         scaled_img = image

#     scaled_img = ndimage.zoom(image, (1.0, 1.0, scale, scale), order=1, prefilter=False)
    
    full_prediction_= net(Variable(torch.from_numpy(image), volatile=True).cuda())
#     full_prediction_ = net('STDCNet1446',19)
    if 'dsn' in method or 'center' in method or 'fuse' in method:
        full_prediction = full_prediction_[-1]
    else:
        full_prediction = full_prediction_[0]

    full_prediction = F.upsample(input=full_prediction, size=(1024, 2048), mode='bilinear', align_corners=True)
    result = full_prediction.cpu().data.numpy().transpose(0,2,3,1)
    return result
def get_confusion_matrix(gt_label, pred_label, class_num):
        """
        Calcute the confusion matrix by given label and pred
        :param gt_label: the ground truth label
        :param pred_label: the pred label
        :param class_num: the nunber of class
        :return: the confusion matrix
        """
        index = (gt_label * class_num + pred_label).astype('int32')
        label_count = np.bincount(index)
        confusion_matrix = np.zeros((class_num, class_num))

        for i_label in range(class_num):
            for i_pred_label in range(class_num):
                cur_index = i_label * class_num + i_pred_label
                if cur_index < len(label_count):
                    confusion_matrix[i_label, i_pred_label] = label_count[cur_index]

        return confusion_matrix
def visulize_attention_ratio(img_path, attention_mask, ratio=0.5, cmap="jet"):
    """
    img_path: 读取图片的位置
    attention_mask: 2-D 的numpy矩阵
    ratio:  放大或缩小图片的比例，可选
    cmap:   attention map的style，可选
    """
    print("load image from: ", img_path)
    # load the image
    img = PILImage.open(img_path, mode='r')
    img_h, img_w = img.size[0], img.size[1]
    plt.subplots(nrows=1, ncols=1, figsize=(0.02 * img_h, 0.02 * img_w))
#     print(img)

    # scale the image
    img_h, img_w = int(img.size[0] * ratio), int(img.size[1] * ratio)
    img = img.resize((img_h, img_w))
    plt.imshow(img, alpha=1)
    plt.axis('off')
    
    # normalize the attention mask
    print(attention_mask)
    mask = cv2.resize(attention_mask, (img_h, img_w))
    normed_mask = mask / mask.max()
    normed_mask = (normed_mask * 255).astype('uint8')
    plt.imshow(normed_mask, alpha=0.5, interpolation='nearest', cmap=cmap)
    plt.savefig("heatmap_nodetail.png")
    plt.show()

# %%
from models.model_stages import BiSeNet
from cityscapes import CityScapes
# %matplotlib inline
def main():
    """Create the model and start the evaluation process."""
#     args = Parameters().parse()

    # file_log = open(args.log_file, "w")
    # sys.stdout = sys.stderr = file_log

#     print("Input arguments:")
#     sys.stdout.flush()
#     for key, val in vars(args).items():
#         print("{:16} {}".format(key, val))

    h, w = map(int, [768,1536])
    input_size = (h, w)

    output_path = './my_predict_train'
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    CRnet = BiSeNet('STDCNet1446', 19,use_boundary_2=False, use_boundary_4=False, 
     use_boundary_8=True, use_boundary_16=False, 
     use_conv_last=False)

    ignore_label = 255
    id_to_trainid = {-1: ignore_label, 0: ignore_label, 1: ignore_label, 2: ignore_label,
          3: ignore_label, 4: ignore_label, 5: ignore_label, 6: ignore_label,
          7: 0, 8: 1, 9: ignore_label, 10: ignore_label, 11: 2, 12: 3, 13: 4,
          14: ignore_label, 15: ignore_label, 16: ignore_label, 17: 5,
          18: ignore_label, 19: 6, 20: 7, 21: 8, 22: 9, 23: 10, 24: 11, 25: 12, 26: 13, 27: 14,
          28: 15, 29: ignore_label, 30: ignore_label, 31: 16, 32: 17, 33: 18}


    os.environ["CUDA_VISIBLE_DEVICES"]='0'
    methodName = 'train_STDC2-Seg_depthwise51/pths'
    print('loading parameters...')
    respth = '/xiaoou/STDC-Seg-master/STDC-Seg-master/checkpoint/{}/'.format(methodName)
    save_pth = os.path.join(respth, 'model_maxmIOU{}.pth'.format(75))
    store_output = 'True'
    
    saved_state_dict = torch.load(save_pth)
    CRnet.load_state_dict(saved_state_dict,False)

    model = nn.DataParallel(CRnet)
    model.eval()
    model.cuda()
#     dspth = '/xiaoou/my_last_project/dataset/cityscapes'
    dspth = '/xiaoou/STDC-Seg-master/STDC-Seg-master/cityscapes'
    randomscale = (0.125, 0.25, 0.375, 0.5, 0.625, 0.75, 0.875, 1.0, 1.125, 1.25, 1.375, 1.5)
    dsval = CityScapes(dspth,cropsize=[1024,2048],mode='val',randomscale=randomscale)
    testloader = data.DataLoader(dsval,
                    batch_size = 2,
                    shuffle = False,
                    num_workers = 2,
                    drop_last = False)

    data_list = []
    confusion_matrix = np.zeros((19,19))

    palette = get_palette(20)

    image_id = 0
    for index, batch in enumerate(testloader):
        if index % 100 == 0:
            print('%d processd'%(index))
            sys.stdout.flush()
        image, label,name = batch
        size = image.shape
#         size = size[0]
        with torch.no_grad():
            if 'val' in 'val':
                output= predict_whole_img_w_label(model, image.numpy(), 19, 
                            'val', scale=float(1), label=Variable(label.long().cuda()))
                
            else:
                output = predict_whole_img(model, image.numpy(),19, 
                    'val', scale=float(1))
    
#     output = np.squeeze(output)
#     print(output.shape)
#     visulize_attention_ratio('/xiaoou/STDC-Seg-master/STDC-Seg-master/cityscapes/leftImg8bit/val/aachen/aachen_000096_000019_leftImg8bit.png',output)
#         print(output.shape)
        seg_pred = np.asarray(np.argmax(output, axis=3), dtype=np.uint8)
        m_seg_pred = ma.masked_array(seg_pred, mask=torch.eq(label, 255))
        ma.set_fill_value(m_seg_pred, 20)
        seg_pred = m_seg_pred
#         seg_pred = np.expand_dims(seg_pred, 1)
#         print(seg_pred.shape)

        for i in range(image.size(0)): 
            image_id += 1
            print('%d th segmentation map generated ...'%(image_id))
            sys.stdout.flush()
            if store_output == 'True':
                output_im = PILImage.fromarray(seg_pred[i])
                output_im.putpalette(palette)
                output_im.save(output_path+'/'+name[i]+'_gtFine_labelIds.png')
#         print(label.shape)
        seg_pred = np.expand_dims(seg_pred, 1)
        seg_gt = np.asarray(label.numpy())#[:,:size[0],:size[1]], dtype=np.int)
#         print(seg_gt.shape)
        ignore_index = seg_gt != 255
        seg_gt = seg_gt[ignore_index]
        
        seg_pred = seg_pred[ignore_index]
        confusion_matrix += get_confusion_matrix(seg_gt, seg_pred, 19)
            
    pos = confusion_matrix.sum(1)
    res = confusion_matrix.sum(0)
    tp = np.diag(confusion_matrix)

    IU_array = (tp / np.maximum(1.0, pos + res - tp))
    mean_IU = IU_array.mean()
    
    print({'meanIU':mean_IU, 'IU_array':IU_array})

    print("confusion matrix\n")
#     print(confusion_matrix)
    sys.stdout.flush()

main()
# Out:
# loading parameters...
# /xiaoou/STDC-Seg-master/STDC-Seg-master/models/model_stages.py:129: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.
#   nn.init.constant(self.W.weight, 0)
# /xiaoou/STDC-Seg-master/STDC-Seg-master/models/model_stages.py:130: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.
#   nn.init.constant(self.W.bias, 0)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-c22cc706a6a7> in <module>
#     121     sys.stdout.flush()
#     122
# --> 123 main()
#
# <ipython-input-3-c22cc706a6a7> in main()
#      41     store_output = 'True'
#      42
# ---> 43     saved_state_dict = torch.load(save_pth)
#      44     CRnet.load_state_dict(saved_state_dict,False)
#      45
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     424         if sys.version_info >= (3, 0) and 'encoding' not in pickle_load_args.keys():
#     425             pickle_load_args['encoding'] = 'utf-8'
# --> 426         return _load(f, map_location, pickle_module, **pickle_load_args)
#     427     finally:
#     428         if new_fd:
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in _load(f, map_location, pickle_module, **pickle_load_args)
#     611     unpickler = pickle_module.Unpickler(f, **pickle_load_args)
#     612     unpickler.persistent_load = persistent_load
# --> 613     result = unpickler.load()
#     614
#     615     deserialized_storage_keys = pickle_module.load(f, **pickle_load_args)
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in persistent_load(saved_id)
#     574                 obj = data_type(size)
#     575                 obj._torch_load_uninitialized = True
# --> 576                 deserialized_objects[root_key] = restore_location(obj, location)
#     577             storage = deserialized_objects[root_key]
#     578             if view_metadata is not None:
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in default_restore_location(storage, location)
#     153 def default_restore_location(storage, location):
#     154     for _, _, fn in _package_registry:
# --> 155         result = fn(storage, location)
#     156         if result is not None:
#     157             return result
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in _cuda_deserialize(obj, location)
#     129 def _cuda_deserialize(obj, location):
#     130     if location.startswith('cuda'):
# --> 131         device = validate_cuda_device(location)
#     132         if getattr(obj, "_torch_load_uninitialized", False):
#     133             storage_type = getattr(torch.cuda, type(obj).__name__)
#
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py in validate_cuda_device(location)
#     113
#     114     if not torch.cuda.is_available():
# --> 115         raise RuntimeError('Attempting to deserialize object on a CUDA '
#     116                            'device but torch.cuda.is_available() is False. '
#     117                            'If you are running on a CPU-only machine, '
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.

# %%
import numpy as np
import cv2
from PIL import Image
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import os

def visulize_attention_ratio(img_path, attention_mask, ratio=0.5, cmap="jet"):
    """
    img_path: 读取图片的位置
    attention_mask: 2-D 的numpy矩阵
    ratio:  放大或缩小图片的比例，可选
    cmap:   attention map的style，可选
    """
    print("load image from: ", img_path)
    # load the image
    img = Image.open(img_path, mode='r')
    img_h, img_w = img.size[0], img.size[1]
    plt.subplots(nrows=1, ncols=1, figsize=(0.02 * img_h, 0.02 * img_w))

    # scale the image
    img_h, img_w = int(img.size[0] * ratio), int(img.size[1] * ratio)
    img = img.resize((img_h, img_w))
    plt.imshow(img, alpha=1)
    plt.axis('off')
    
    # normalize the attention mask
    mask = cv2.resize(attention_mask, (img_h, img_w))
    normed_mask = mask / mask.max()
    normed_mask = (normed_mask * 255).astype('uint8')
    plt.imshow(normed_mask, alpha=0.5, interpolation='nearest', cmap=cmap)
visulize_attention_ratio('/xiaoou/STDC-Seg-master/STDC-Seg-master/cityscapes/leftImg8bit/val/aachen/aachen_000096_000019_leftImg8bit.png',output,)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ebae8bdb0bff> in <module>
#      31     normed_mask = (normed_mask * 255).astype('uint8')
#      32     plt.imshow(normed_mask, alpha=0.5, interpolation='nearest', cmap=cmap)
# ---> 33 visulize_attention_ratio('/xiaoou/STDC-Seg-master/STDC-Seg-master/cityscapes/leftImg8bit/val/aachen/aachen_000096_000019_leftImg8bit.png',output,)
#
# NameError: name 'output' is not defined

# %%
##+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
## Created by: RainbowSecret
## Microsoft Research
## yuyua@microsoft.com
## Copyright (c) 2018
##
## This source code is licensed under the MIT-style license found in the
## LICENSE file in the root directory of this source tree 
##+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
import argparse
import scipy
from scipy import ndimage
import torch, cv2
import numpy as np
import sys
import pdb

from torch.autograd import Variable
import torchvision.models as models
import torch.nn.functional as F
from torch.utils import data
from collections import OrderedDict
# from dataset import get_segmentation_dataset
# from network import get_segmentation_model
# from config import Parameters
import os
import scipy.ndimage as nd
from math import ceil
from PIL import Image as PILImage

import matplotlib.pyplot as plt
import torch.nn as nn
# torch_ver = torch.__version__[:3]
from models.model_stages import BiSeNet
from cityscapes import CityScapes


def get_palette(num_cls):
    """ Returns the color map for visualizing the segmentation mask.
    Args:
        num_cls: Number of classes
    Returns:
        The color map
    """

    n = num_cls
    palette = [0] * (n * 3)
    for j in range(0, n):
        lab = j
        palette[j * 3 + 0] = 0
        palette[j * 3 + 1] = 0
        palette[j * 3 + 2] = 0
        i = 0
        while lab:
            palette[j * 3 + 0] |= (((lab >> 0) & 1) << (7 - i))
            palette[j * 3 + 1] |= (((lab >> 1) & 1) << (7 - i))
            palette[j * 3 + 2] |= (((lab >> 2) & 1) << (7 - i))
            i += 1
            lab >>= 3
    return palette


def pad_image(img, target_size):
    """Pad an image up to the target size."""
    rows_missing = target_size[0] - img.shape[2]
    cols_missing = target_size[1] - img.shape[3]
    padded_img = np.pad(img, ((0, 0), (0, 0), (0, rows_missing), (0, cols_missing)), 'constant')
    return padded_img


def predict_sliding(net, image, tile_size, classes, method, scale=1):
    if scale != 1:
        scaled_img = ndimage.zoom(image, (1.0, 1.0, scale, scale), order=1, prefilter=False)
    else:
        scaled_img = image

    N_, C_, H_, W_ = scaled_img.shape

    if torch_ver == '0.4':
        interp = nn.Upsample(size=tile_size, mode='bilinear', align_corners=True)
    else:
        interp = nn.Upsample(size=tile_size, mode='bilinear')

    full_probs = np.zeros((N_, H_, W_, classes))
    count_predictions = np.zeros((N_, H_, W_, classes))
    overlap = 0
    stride_h = ceil(tile_size[0] * (1 - overlap))
    stride_w = ceil(tile_size[1] * (1 - overlap))
    tile_rows = int(ceil((H_ - tile_size[0]) / stride_h) + 1)  # strided convolution formula
    tile_cols = int(ceil((W_ - tile_size[1]) / stride_w) + 1)
    print("Need %i x %i prediction tiles @ stride %i px, %i py" % (tile_cols, tile_rows, stride_h, stride_w))

    tile_counter = 0

    for row in range(tile_rows):
        for col in range(tile_cols):
            x1 = int(col * stride_w)
            y1 = int(row * stride_h)
            x2 = min(x1 + tile_size[1], W_)
            y2 = min(y1 + tile_size[0], H_)
            x1 = max(int(x2 - tile_size[1]), 0)  # for portrait images the x1 underflows sometimes
            y1 = max(int(y2 - tile_size[0]), 0)  # for very few rows y1 underflows

            img = scaled_img[:, :, y1:y2, x1:x2]
            padded_img = pad_image(img, tile_size)
            tile_counter += 1
            print("Predicting tile %i" % tile_counter)
            padded_prediction_ = net(Variable(torch.from_numpy(padded_img), volatile=True).cuda(), )
    
            if 'dsn' in method or 'center' in method or 'fuse' in method:
                padded_prediction = padded_prediction_[-1]
            else:
                padded_prediction = padded_prediction_

            padded_prediction = F.upsample(input=padded_prediction, size=tile_size, mode='bilinear', align_corners=True)
            padded_prediction = padded_prediction.cpu().data.numpy().transpose(0,2,3,1)                
            # padded_prediction = interp(padded_prediction).cpu().data.numpy().transpose(0,2,3,1)
            prediction = padded_prediction[:, 0:img.shape[2], 0:img.shape[3], :]
            count_predictions[:, y1:y2, x1:x2] += 1
            full_probs[:, y1:y2, x1:x2] += prediction 

    full_probs /= count_predictions
    full_probs = ndimage.zoom(full_probs, (1., 1./scale, 1./scale, 1.),
        order=1, prefilter=False)
    return full_probs


def predict_whole_img(net, image, classes, method, scale):
    """
         Predict the whole image w/o using multiple crops.
         The scale specify whether rescale the input image before predicting the results.
    """
    N_, C_, H_, W_ = image.shape
    torch_ver = 1.3

#     if torch_ver == '0.4':
#         interp = nn.Upsample(size=(H_, W_), mode='bilinear', align_corners=True)
#     else:
#         interp = nn.Upsample(size=(H_, W_), mode='bilinear')

#     bug
#     if scale > 1:
#         scaled_img = ndimage.zoom(image, (1.0, 1.0, scale, scale), order=1, prefilter=False)
#     else:
#         scaled_img = image

#     scaled_img = ndimage.zoom(image, (1.0, 1.0, scale, scale), order=1, prefilter=False)
    
    full_prediction_ = net(Variable(torch.from_numpy(image), volatile=True).cuda())
    if 'dsn' in method:
        full_prediction = full_prediction_[-1]
    else:
        full_prediction = full_prediction_[0]

    if torch_ver == '0.4':
        full_prediction = F.upsample(input=full_prediction, size=(1024, 2048), mode='bilinear', align_corners=True)
    else:
        full_prediction = F.upsample(input=full_prediction, size=(1024, 2048), mode='bilinear')
    
    result = full_prediction.cpu().data.numpy().transpose(0,2,3,1)

    # result = interp(full_prediction).cpu().data.numpy().transpose(0,2,3,1)
    return result


def predict_multi_scale(net, image, scales, classes, flip_evaluation, method):
    """
    Predict an image by looking at it with different scales.
        We choose the "predict_whole_img" for the image with less than the original input size,
        for the input of larger size, we would choose the cropping method to ensure that GPU memory is enough.
    """
    N_, C_, H_, W_ = image.shape
    full_probs = np.zeros((N_, H_, W_, classes))  
    for scale in scales:
        scale = float(scale)
        print("Predicting image scaled by %f" % scale)
        sys.stdout.flush()
        if scale <= 1.0:
            scaled_probs = predict_whole_img(net, image, classes, method, scale=scale)
        else:        
            scaled_probs = predict_sliding(net, image, (1024,2048), classes, method, scale=scale)
        if flip_evaluation == 'True':
            if scale <= 1.0:
                flip_scaled_probs = predict_whole_img(net, image[:,:,:,::-1].copy(), classes, method, scale=scale)
            else:
                flip_scaled_probs = predict_sliding(net, image[:,:,:,::-1].copy(), (1024,2048), classes, method, scale=scale)
            scaled_probs = 0.5 * (scaled_probs + flip_scaled_probs[:,:,::-1])
        full_probs += scaled_probs
    full_probs /= len(scales)
    return full_probs


def id2trainId(label, id_to_trainid, reverse=False):
        label_copy = label.copy()
        if reverse:
            for v, k in id_to_trainid.items():
                label_copy[label == k] = v
        else:
            for k, v in id_to_trainid.items():
                label_copy[label == k] = v
        return label_copy


def main():
    """Create the model and start the evaluation process."""
#     args = Parameters().parse()

    # file_log = open(args.log_file, "w")
    # sys.stdout = sys.stderr = file_log

#     print("Input arguments:")
#     for key, val in vars(args).items():
#         print("{:16} {}".format(key, val))
#     sys.stdout.flush()

    h, w = map(int, [768,1536])
    input_size = (h, w)
    ignore_label= 255
    output_path = '/xiaoou/STDC-Seg-master/STDC-Seg-master/predict_submit_74.7'
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    CRnet = BiSeNet('STDCNet1446', 19,use_boundary_2=False, use_boundary_4=False, 
     use_boundary_8=True, use_boundary_16=False, 
     use_conv_last=False)

    os.environ["CUDA_VISIBLE_DEVICES"]='0'
    
    methodName = 'train_STDC2-Seg_depthwise60/pths'
    print('loading parameters...')
    respth = '/xiaoou/STDC-Seg-master/STDC-Seg-master/checkpoint/{}/'.format(methodName)
    save_pth = os.path.join(respth, 'model_maxmIOU{}.pth'.format(75))
    store_output = 'True'
    saved_state_dict = torch.load(save_pth)
    CRnet.load_state_dict(saved_state_dict,False)

    model = nn.DataParallel(CRnet)
    model.eval()
    model.cuda()
    dspth = '/xiaoou/my_last_project/dataset/cityscapes'
    randomscale = (0.125, 0.25, 0.375, 0.5, 0.625, 0.75, 0.875, 1.0, 1.125, 1.25, 1.375, 1.5)
    dsval = CityScapes(dspth,cropsize=[1024,2048],mode='test',randomscale=randomscale)
    testloader = data.DataLoader(dsval,
                    batch_size = 2,
                    shuffle = False,
                    num_workers = 2,
                    drop_last = False)

    data_list = []
    confusion_matrix = np.zeros((19,19))
    palette = get_palette(256)

    id_to_trainid = {-1: ignore_label, 0: ignore_label, 1: ignore_label, 2: ignore_label,
                  3: ignore_label, 4: ignore_label, 5: ignore_label, 6: ignore_label,
                  7: 0, 8: 1, 9: ignore_label, 10: ignore_label, 11: 2, 12: 3, 13: 4,
                  14: ignore_label, 15: ignore_label, 16: ignore_label, 17: 5,
                  18: ignore_label, 19: 6, 20: 7, 21: 8, 22: 9, 23: 10, 24: 11, 25: 12, 26: 13, 27: 14,
                  28: 15, 29: ignore_label, 30: ignore_label, 31: 16, 32: 17, 33: 18}
    image_id = 0
    for index, batch in enumerate(testloader):
        if index % 100 == 0:
            print('%d processd'%(index))
        image, name = batch
        size = image.shape
        with torch.no_grad():
            if 'val' in 'test': 
                output = predict_multi_scale(model, image.numpy(), ([0.75, 1, 1.25]), 
                    args.num_classes, args.use_flip, args.method)
            else:
                output = predict_whole_img(model, image.numpy(),19, 
                    'test', scale=float(1))


        seg_pred = np.asarray(np.argmax(output, axis=3), dtype=np.uint8)
        seg_pred = id2trainId(seg_pred, id_to_trainid, reverse=True)

        for i in range(image.size(0)): 
            image_id += 1
            print('%d th segmentation map generated ...'%(image_id))
            sys.stdout.flush()
            if store_output == 'True':
                output_im = PILImage.fromarray(seg_pred[i])
                output_im.putpalette(palette)
                output_im.save(output_path+'/'+name[i]+'_gtFine_labelIds.png')

if __name__ == '__main__':
    main()
# Out:
# /xiaoou/STDC-Seg-master/STDC-Seg-master/models/model_stages.py:129: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.
#   nn.init.constant(self.W.weight, 0)
# /xiaoou/STDC-Seg-master/STDC-Seg-master/models/model_stages.py:130: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.
#   nn.init.constant(self.W.bias, 0)
# loading parameters...
# self.mode test
# self.len test 1525
# 0 processd
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:149: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2404: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2494: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# 1 th segmentation map generated ...
# 2 th segmentation map generated ...
# 3 th segmentation map generated ...
# 4 th segmentation map generated ...
# 5 th segmentation map generated ...
# 6 th segmentation map generated ...
# 7 th segmentation map generated ...
# 8 th segmentation map generated ...
# 9 th segmentation map generated ...
# 10 th segmentation map generated ...
# 11 th segmentation map generated ...
# 12 th segmentation map generated ...
# 13 th segmentation map generated ...
# 14 th segmentation map generated ...
# 15 th segmentation map generated ...
# 16 th segmentation map generated ...
# 17 th segmentation map generated ...
# 18 th segmentation map generated ...
# 19 th segmentation map generated ...
# 20 th segmentation map generated ...
# 21 th segmentation map generated ...
# 22 th segmentation map generated ...
# 23 th segmentation map generated ...
# 24 th segmentation map generated ...
# 25 th segmentation map generated ...
# 26 th segmentation map generated ...
# 27 th segmentation map generated ...
# 28 th segmentation map generated ...
# 29 th segmentation map generated ...
# 30 th segmentation map generated ...
# 31 th segmentation map generated ...
# 32 th segmentation map generated ...
# 33 th segmentation map generated ...
# 34 th segmentation map generated ...
# 35 th segmentation map generated ...
# 36 th segmentation map generated ...
# 37 th segmentation map generated ...
# 38 th segmentation map generated ...
# 39 th segmentation map generated ...
# 40 th segmentation map generated ...
# 41 th segmentation map generated ...
# 42 th segmentation map generated ...
# 43 th segmentation map generated ...
# 44 th segmentation map generated ...
# 45 th segmentation map generated ...
# 46 th segmentation map generated ...
# 47 th segmentation map generated ...
# 48 th segmentation map generated ...
# 49 th segmentation map generated ...
# 50 th segmentation map generated ...
# 51 th segmentation map generated ...
# 52 th segmentation map generated ...
# 53 th segmentation map generated ...
# 54 th segmentation map generated ...
# 55 th segmentation map generated ...
# 56 th segmentation map generated ...
# 57 th segmentation map generated ...
# 58 th segmentation map generated ...
# 59 th segmentation map generated ...
# 60 th segmentation map generated ...
# 61 th segmentation map generated ...
# 62 th segmentation map generated ...
# 63 th segmentation map generated ...
# 64 th segmentation map generated ...
# 65 th segmentation map generated ...
# 66 th segmentation map generated ...
# 67 th segmentation map generated ...
# 68 th segmentation map generated ...
# 69 th segmentation map generated ...
# 70 th segmentation map generated ...
# 71 th segmentation map generated ...
# 72 th segmentation map generated ...
# 73 th segmentation map generated ...
# 74 th segmentation map generated ...
# 75 th segmentation map generated ...
# 76 th segmentation map generated ...
# 77 th segmentation map generated ...
# 78 th segmentation map generated ...
# 79 th segmentation map generated ...
# 80 th segmentation map generated ...
# 81 th segmentation map generated ...
# 82 th segmentation map generated ...
# 83 th segmentation map generated ...
# 84 th segmentation map generated ...
# 85 th segmentation map generated ...
# 86 th segmentation map generated ...
# 87 th segmentation map generated ...
# 88 th segmentation map generated ...
# 89 th segmentation map generated ...
# 90 th segmentation map generated ...
# 91 th segmentation map generated ...
# 92 th segmentation map generated ...
# 93 th segmentation map generated ...
# 94 th segmentation map generated ...
# 95 th segmentation map generated ...
# 96 th segmentation map generated ...
# 97 th segmentation map generated ...
# 98 th segmentation map generated ...
# 99 th segmentation map generated ...
# 100 th segmentation map generated ...
# 101 th segmentation map generated ...
# 102 th segmentation map generated ...
# 103 th segmentation map generated ...
# 104 th segmentation map generated ...
# 105 th segmentation map generated ...
# 106 th segmentation map generated ...
# 107 th segmentation map generated ...
# 108 th segmentation map generated ...
# 109 th segmentation map generated ...
# 110 th segmentation map generated ...
# 111 th segmentation map generated ...
# 112 th segmentation map generated ...
# 113 th segmentation map generated ...
# 114 th segmentation map generated ...
# 115 th segmentation map generated ...
# 116 th segmentation map generated ...
# 117 th segmentation map generated ...
# 118 th segmentation map generated ...
# 119 th segmentation map generated ...
# 120 th segmentation map generated ...
# 121 th segmentation map generated ...
# 122 th segmentation map generated ...
# 123 th segmentation map generated ...
# 124 th segmentation map generated ...
# 125 th segmentation map generated ...
# 126 th segmentation map generated ...
# 127 th segmentation map generated ...
# 128 th segmentation map generated ...
# 129 th segmentation map generated ...
# 130 th segmentation map generated ...
# 131 th segmentation map generated ...
# 132 th segmentation map generated ...
# 133 th segmentation map generated ...
# 134 th segmentation map generated ...
# 135 th segmentation map generated ...
# 136 th segmentation map generated ...
# 137 th segmentation map generated ...
# 138 th segmentation map generated ...
# 139 th segmentation map generated ...
# 140 th segmentation map generated ...
# 141 th segmentation map generated ...
# 142 th segmentation map generated ...
# 143 th segmentation map generated ...
# 144 th segmentation map generated ...
# 145 th segmentation map generated ...
# 146 th segmentation map generated ...
# 147 th segmentation map generated ...
# 148 th segmentation map generated ...
# 149 th segmentation map generated ...
# 150 th segmentation map generated ...
# 151 th segmentation map generated ...
# 152 th segmentation map generated ...
# 153 th segmentation map generated ...
# 154 th segmentation map generated ...
# 155 th segmentation map generated ...
# 156 th segmentation map generated ...
# 157 th segmentation map generated ...
# 158 th segmentation map generated ...
# 159 th segmentation map generated ...
# 160 th segmentation map generated ...
# 161 th segmentation map generated ...
# 162 th segmentation map generated ...
# 163 th segmentation map generated ...
# 164 th segmentation map generated ...
# 165 th segmentation map generated ...
# 166 th segmentation map generated ...
# 167 th segmentation map generated ...
# 168 th segmentation map generated ...
# 169 th segmentation map generated ...
# 170 th segmentation map generated ...
# 171 th segmentation map generated ...
# 172 th segmentation map generated ...
# 173 th segmentation map generated ...
# 174 th segmentation map generated ...
# 175 th segmentation map generated ...
# 176 th segmentation map generated ...
# 177 th segmentation map generated ...
# 178 th segmentation map generated ...
# 179 th segmentation map generated ...
# 180 th segmentation map generated ...
# 181 th segmentation map generated ...
# 182 th segmentation map generated ...
# 183 th segmentation map generated ...
# 184 th segmentation map generated ...
# 185 th segmentation map generated ...
# 186 th segmentation map generated ...
# 187 th segmentation map generated ...
# 188 th segmentation map generated ...
# 189 th segmentation map generated ...
# 190 th segmentation map generated ...
# 191 th segmentation map generated ...
# 192 th segmentation map generated ...
# 193 th segmentation map generated ...
# 194 th segmentation map generated ...
# 195 th segmentation map generated ...
# 196 th segmentation map generated ...
# 197 th segmentation map generated ...
# 198 th segmentation map generated ...
# 199 th segmentation map generated ...
# 200 th segmentation map generated ...
# 100 processd
# 201 th segmentation map generated ...
# 202 th segmentation map generated ...
# 203 th segmentation map generated ...
# 204 th segmentation map generated ...
# 205 th segmentation map generated ...
# 206 th segmentation map generated ...
# 207 th segmentation map generated ...
# 208 th segmentation map generated ...
# 209 th segmentation map generated ...
# 210 th segmentation map generated ...
# 211 th segmentation map generated ...
# 212 th segmentation map generated ...
# 213 th segmentation map generated ...
# 214 th segmentation map generated ...
# 215 th segmentation map generated ...
# 216 th segmentation map generated ...
# 217 th segmentation map generated ...
# 218 th segmentation map generated ...
# 219 th segmentation map generated ...
# 220 th segmentation map generated ...
# 221 th segmentation map generated ...
# 222 th segmentation map generated ...
# 223 th segmentation map generated ...
# 224 th segmentation map generated ...
# 225 th segmentation map generated ...
# 226 th segmentation map generated ...
# 227 th segmentation map generated ...
# 228 th segmentation map generated ...
# 229 th segmentation map generated ...
# 230 th segmentation map generated ...
# 231 th segmentation map generated ...
# 232 th segmentation map generated ...
# 233 th segmentation map generated ...
# 234 th segmentation map generated ...
# 235 th segmentation map generated ...
# 236 th segmentation map generated ...
# 237 th segmentation map generated ...
# 238 th segmentation map generated ...
# 239 th segmentation map generated ...
# 240 th segmentation map generated ...
# 241 th segmentation map generated ...
# 242 th segmentation map generated ...
# 243 th segmentation map generated ...
# 244 th segmentation map generated ...
# 245 th segmentation map generated ...
# 246 th segmentation map generated ...
# 247 th segmentation map generated ...
# 248 th segmentation map generated ...
# 249 th segmentation map generated ...
# 250 th segmentation map generated ...
# 251 th segmentation map generated ...
# 252 th segmentation map generated ...
# 253 th segmentation map generated ...
# 254 th segmentation map generated ...
# 255 th segmentation map generated ...
# 256 th segmentation map generated ...
# 257 th segmentation map generated ...
# 258 th segmentation map generated ...
# 259 th segmentation map generated ...
# 260 th segmentation map generated ...
# 261 th segmentation map generated ...
# 262 th segmentation map generated ...
# 263 th segmentation map generated ...
# 264 th segmentation map generated ...
# 265 th segmentation map generated ...
# 266 th segmentation map generated ...
# 267 th segmentation map generated ...
# 268 th segmentation map generated ...
# 269 th segmentation map generated ...
# 270 th segmentation map generated ...
# 271 th segmentation map generated ...
# 272 th segmentation map generated ...
# 273 th segmentation map generated ...
# 274 th segmentation map generated ...
# 275 th segmentation map generated ...
# 276 th segmentation map generated ...
# 277 th segmentation map generated ...
# 278 th segmentation map generated ...
# 279 th segmentation map generated ...
# 280 th segmentation map generated ...
# 281 th segmentation map generated ...
# 282 th segmentation map generated ...
# 283 th segmentation map generated ...
# 284 th segmentation map generated ...
# 285 th segmentation map generated ...
# 286 th segmentation map generated ...
# 287 th segmentation map generated ...
# 288 th segmentation map generated ...
# 289 th segmentation map generated ...
# 290 th segmentation map generated ...
# 291 th segmentation map generated ...
# 292 th segmentation map generated ...
# 293 th segmentation map generated ...
# 294 th segmentation map generated ...
# 295 th segmentation map generated ...
# 296 th segmentation map generated ...
# 297 th segmentation map generated ...
# 298 th segmentation map generated ...
# 299 th segmentation map generated ...
# 300 th segmentation map generated ...
# 301 th segmentation map generated ...
# 302 th segmentation map generated ...
# 303 th segmentation map generated ...
# 304 th segmentation map generated ...
# 305 th segmentation map generated ...
# 306 th segmentation map generated ...
# 307 th segmentation map generated ...
# 308 th segmentation map generated ...
# 309 th segmentation map generated ...
# 310 th segmentation map generated ...
# 311 th segmentation map generated ...
# 312 th segmentation map generated ...
# 313 th segmentation map generated ...
# 314 th segmentation map generated ...
# 315 th segmentation map generated ...
# 316 th segmentation map generated ...
# 317 th segmentation map generated ...
# 318 th segmentation map generated ...
# 319 th segmentation map generated ...
# 320 th segmentation map generated ...
# 321 th segmentation map generated ...
# 322 th segmentation map generated ...
# 323 th segmentation map generated ...
# 324 th segmentation map generated ...
# 325 th segmentation map generated ...
# 326 th segmentation map generated ...
# 327 th segmentation map generated ...
# 328 th segmentation map generated ...
# 329 th segmentation map generated ...
# 330 th segmentation map generated ...
# 331 th segmentation map generated ...
# 332 th segmentation map generated ...
# 333 th segmentation map generated ...
# 334 th segmentation map generated ...
# 335 th segmentation map generated ...
# 336 th segmentation map generated ...
# 337 th segmentation map generated ...
# 338 th segmentation map generated ...
# 339 th segmentation map generated ...
# 340 th segmentation map generated ...
# 341 th segmentation map generated ...
# 342 th segmentation map generated ...
# 343 th segmentation map generated ...
# 344 th segmentation map generated ...
# 345 th segmentation map generated ...
# 346 th segmentation map generated ...
# 347 th segmentation map generated ...
# 348 th segmentation map generated ...
# 349 th segmentation map generated ...
# 350 th segmentation map generated ...
# 351 th segmentation map generated ...
# 352 th segmentation map generated ...
# 353 th segmentation map generated ...
# 354 th segmentation map generated ...
# 355 th segmentation map generated ...
# 356 th segmentation map generated ...
# 357 th segmentation map generated ...
# 358 th segmentation map generated ...
# 359 th segmentation map generated ...
# 360 th segmentation map generated ...
# 361 th segmentation map generated ...
# 362 th segmentation map generated ...
# 363 th segmentation map generated ...
# 364 th segmentation map generated ...
# 365 th segmentation map generated ...
# 366 th segmentation map generated ...
# 367 th segmentation map generated ...
# 368 th segmentation map generated ...
# 369 th segmentation map generated ...
# 370 th segmentation map generated ...
# 371 th segmentation map generated ...
# 372 th segmentation map generated ...
# 373 th segmentation map generated ...
# 374 th segmentation map generated ...
# 375 th segmentation map generated ...
# 376 th segmentation map generated ...
# 377 th segmentation map generated ...
# 378 th segmentation map generated ...
# 379 th segmentation map generated ...
# 380 th segmentation map generated ...
# 381 th segmentation map generated ...
# 382 th segmentation map generated ...
# 383 th segmentation map generated ...
# 384 th segmentation map generated ...
# 385 th segmentation map generated ...
# 386 th segmentation map generated ...
# 387 th segmentation map generated ...
# 388 th segmentation map generated ...
# 389 th segmentation map generated ...
# 390 th segmentation map generated ...
# 391 th segmentation map generated ...
# 392 th segmentation map generated ...
# 393 th segmentation map generated ...
# 394 th segmentation map generated ...
# 395 th segmentation map generated ...
# 396 th segmentation map generated ...
# 397 th segmentation map generated ...
# 398 th segmentation map generated ...
# 399 th segmentation map generated ...
# 400 th segmentation map generated ...
# 200 processd
# 401 th segmentation map generated ...
# 402 th segmentation map generated ...
# 403 th segmentation map generated ...
# 404 th segmentation map generated ...
# 405 th segmentation map generated ...
# 406 th segmentation map generated ...
# 407 th segmentation map generated ...
# 408 th segmentation map generated ...
# 409 th segmentation map generated ...
# 410 th segmentation map generated ...
# 411 th segmentation map generated ...
# 412 th segmentation map generated ...
# 413 th segmentation map generated ...
# 414 th segmentation map generated ...
# 415 th segmentation map generated ...
# 416 th segmentation map generated ...
# 417 th segmentation map generated ...
# 418 th segmentation map generated ...
# 419 th segmentation map generated ...
# 420 th segmentation map generated ...
# 421 th segmentation map generated ...
# 422 th segmentation map generated ...
# 423 th segmentation map generated ...
# 424 th segmentation map generated ...
# 425 th segmentation map generated ...
# 426 th segmentation map generated ...
# 427 th segmentation map generated ...
# 428 th segmentation map generated ...
# 429 th segmentation map generated ...
# 430 th segmentation map generated ...
# 431 th segmentation map generated ...
# 432 th segmentation map generated ...
# 433 th segmentation map generated ...
# 434 th segmentation map generated ...
# 435 th segmentation map generated ...
# 436 th segmentation map generated ...
# 437 th segmentation map generated ...
# 438 th segmentation map generated ...
# 439 th segmentation map generated ...
# 440 th segmentation map generated ...
# 441 th segmentation map generated ...
# 442 th segmentation map generated ...
# 443 th segmentation map generated ...
# 444 th segmentation map generated ...
# 445 th segmentation map generated ...
# 446 th segmentation map generated ...
# 447 th segmentation map generated ...
# 448 th segmentation map generated ...
# 449 th segmentation map generated ...
# 450 th segmentation map generated ...
# 451 th segmentation map generated ...
# 452 th segmentation map generated ...
# 453 th segmentation map generated ...
# 454 th segmentation map generated ...
# 455 th segmentation map generated ...
# 456 th segmentation map generated ...
# 457 th segmentation map generated ...
# 458 th segmentation map generated ...
# 459 th segmentation map generated ...
# 460 th segmentation map generated ...
# 461 th segmentation map generated ...
# 462 th segmentation map generated ...
# 463 th segmentation map generated ...
# 464 th segmentation map generated ...
# 465 th segmentation map generated ...
# 466 th segmentation map generated ...
# 467 th segmentation map generated ...
# 468 th segmentation map generated ...
# 469 th segmentation map generated ...
# 470 th segmentation map generated ...
# 471 th segmentation map generated ...
# 472 th segmentation map generated ...
# 473 th segmentation map generated ...
# 474 th segmentation map generated ...
# 475 th segmentation map generated ...
# 476 th segmentation map generated ...
# 477 th segmentation map generated ...
# 478 th segmentation map generated ...
# 479 th segmentation map generated ...
# 480 th segmentation map generated ...
# 481 th segmentation map generated ...
# 482 th segmentation map generated ...
# 483 th segmentation map generated ...
# 484 th segmentation map generated ...
# 485 th segmentation map generated ...
# 486 th segmentation map generated ...
# 487 th segmentation map generated ...
# 488 th segmentation map generated ...
# 489 th segmentation map generated ...
# 490 th segmentation map generated ...
# 491 th segmentation map generated ...
# 492 th segmentation map generated ...
# 493 th segmentation map generated ...
# 494 th segmentation map generated ...
# 495 th segmentation map generated ...
# 496 th segmentation map generated ...
# 497 th segmentation map generated ...
# 498 th segmentation map generated ...
# 499 th segmentation map generated ...
# 500 th segmentation map generated ...
# 501 th segmentation map generated ...
# 502 th segmentation map generated ...
# 503 th segmentation map generated ...
# 504 th segmentation map generated ...
# 505 th segmentation map generated ...
# 506 th segmentation map generated ...
# 507 th segmentation map generated ...
# 508 th segmentation map generated ...
# 509 th segmentation map generated ...
# 510 th segmentation map generated ...
# 511 th segmentation map generated ...
# 512 th segmentation map generated ...
# 513 th segmentation map generated ...
# 514 th segmentation map generated ...
# 515 th segmentation map generated ...
# 516 th segmentation map generated ...
# 517 th segmentation map generated ...
# 518 th segmentation map generated ...
# 519 th segmentation map generated ...
# 520 th segmentation map generated ...
# 521 th segmentation map generated ...
# 522 th segmentation map generated ...
# 523 th segmentation map generated ...
# 524 th segmentation map generated ...
# 525 th segmentation map generated ...
# 526 th segmentation map generated ...
# 527 th segmentation map generated ...
# 528 th segmentation map generated ...
# 529 th segmentation map generated ...
# 530 th segmentation map generated ...
# 531 th segmentation map generated ...
# 532 th segmentation map generated ...
# 533 th segmentation map generated ...
# 534 th segmentation map generated ...
# 535 th segmentation map generated ...
# 536 th segmentation map generated ...
# 537 th segmentation map generated ...
# 538 th segmentation map generated ...
# 539 th segmentation map generated ...
# 540 th segmentation map generated ...
# 541 th segmentation map generated ...
# 542 th segmentation map generated ...
# 543 th segmentation map generated ...
# 544 th segmentation map generated ...
# 545 th segmentation map generated ...
# 546 th segmentation map generated ...
# 547 th segmentation map generated ...
# 548 th segmentation map generated ...
# 549 th segmentation map generated ...
# 550 th segmentation map generated ...
# 551 th segmentation map generated ...
# 552 th segmentation map generated ...
# 553 th segmentation map generated ...
# 554 th segmentation map generated ...
# 555 th segmentation map generated ...
# 556 th segmentation map generated ...
# 557 th segmentation map generated ...
# 558 th segmentation map generated ...
# 559 th segmentation map generated ...
# 560 th segmentation map generated ...
# 561 th segmentation map generated ...
# 562 th segmentation map generated ...
# 563 th segmentation map generated ...
# 564 th segmentation map generated ...
# 565 th segmentation map generated ...
# 566 th segmentation map generated ...
# 567 th segmentation map generated ...
# 568 th segmentation map generated ...
# 569 th segmentation map generated ...
# 570 th segmentation map generated ...
# 571 th segmentation map generated ...
# 572 th segmentation map generated ...
# 573 th segmentation map generated ...
# 574 th segmentation map generated ...
# 575 th segmentation map generated ...
# 576 th segmentation map generated ...
# 577 th segmentation map generated ...
# 578 th segmentation map generated ...
# 579 th segmentation map generated ...
# 580 th segmentation map generated ...
# 581 th segmentation map generated ...
# 582 th segmentation map generated ...
# 583 th segmentation map generated ...
# 584 th segmentation map generated ...
# 585 th segmentation map generated ...
# 586 th segmentation map generated ...
# 587 th segmentation map generated ...
# 588 th segmentation map generated ...
# 589 th segmentation map generated ...
# 590 th segmentation map generated ...
# 591 th segmentation map generated ...
# 592 th segmentation map generated ...
# 593 th segmentation map generated ...
# 594 th segmentation map generated ...
# 595 th segmentation map generated ...
# 596 th segmentation map generated ...
# 597 th segmentation map generated ...
# 598 th segmentation map generated ...
# 599 th segmentation map generated ...
# 600 th segmentation map generated ...
# 300 processd
# 601 th segmentation map generated ...
# 602 th segmentation map generated ...
# 603 th segmentation map generated ...
# 604 th segmentation map generated ...
# 605 th segmentation map generated ...
# 606 th segmentation map generated ...
# 607 th segmentation map generated ...
# 608 th segmentation map generated ...
# 609 th segmentation map generated ...
# 610 th segmentation map generated ...
# 611 th segmentation map generated ...
# 612 th segmentation map generated ...
# 613 th segmentation map generated ...
# 614 th segmentation map generated ...
# 615 th segmentation map generated ...
# 616 th segmentation map generated ...
# 617 th segmentation map generated ...
# 618 th segmentation map generated ...
# 619 th segmentation map generated ...
# 620 th segmentation map generated ...
# 621 th segmentation map generated ...
# 622 th segmentation map generated ...
# 623 th segmentation map generated ...
# 624 th segmentation map generated ...
# 625 th segmentation map generated ...
# 626 th segmentation map generated ...
# 627 th segmentation map generated ...
# 628 th segmentation map generated ...
# 629 th segmentation map generated ...
# 630 th segmentation map generated ...
# 631 th segmentation map generated ...
# 632 th segmentation map generated ...
# 633 th segmentation map generated ...
# 634 th segmentation map generated ...
# 635 th segmentation map generated ...
# 636 th segmentation map generated ...
# 637 th segmentation map generated ...
# 638 th segmentation map generated ...
# 639 th segmentation map generated ...
# 640 th segmentation map generated ...
# 641 th segmentation map generated ...
# 642 th segmentation map generated ...
# 643 th segmentation map generated ...
# 644 th segmentation map generated ...
# 645 th segmentation map generated ...
# 646 th segmentation map generated ...
# 647 th segmentation map generated ...
# 648 th segmentation map generated ...
# 649 th segmentation map generated ...
# 650 th segmentation map generated ...
# 651 th segmentation map generated ...
# 652 th segmentation map generated ...
# 653 th segmentation map generated ...
# 654 th segmentation map generated ...
# 655 th segmentation map generated ...
# 656 th segmentation map generated ...
# 657 th segmentation map generated ...
# 658 th segmentation map generated ...
# 659 th segmentation map generated ...
# 660 th segmentation map generated ...
# 661 th segmentation map generated ...
# 662 th segmentation map generated ...
# 663 th segmentation map generated ...
# 664 th segmentation map generated ...
# 665 th segmentation map generated ...
# 666 th segmentation map generated ...
# 667 th segmentation map generated ...
# 668 th segmentation map generated ...
# 669 th segmentation map generated ...
# 670 th segmentation map generated ...
# 671 th segmentation map generated ...
# 672 th segmentation map generated ...
# 673 th segmentation map generated ...
# 674 th segmentation map generated ...
# 675 th segmentation map generated ...
# 676 th segmentation map generated ...
# 677 th segmentation map generated ...
# 678 th segmentation map generated ...
# 679 th segmentation map generated ...
# 680 th segmentation map generated ...
# 681 th segmentation map generated ...
# 682 th segmentation map generated ...
# 683 th segmentation map generated ...
# 684 th segmentation map generated ...
# 685 th segmentation map generated ...
# 686 th segmentation map generated ...
# 687 th segmentation map generated ...
# 688 th segmentation map generated ...
# 689 th segmentation map generated ...
# 690 th segmentation map generated ...
# 691 th segmentation map generated ...
# 692 th segmentation map generated ...
# 693 th segmentation map generated ...
# 694 th segmentation map generated ...
# 695 th segmentation map generated ...
# 696 th segmentation map generated ...
# 697 th segmentation map generated ...
# 698 th segmentation map generated ...
# 699 th segmentation map generated ...
# 700 th segmentation map generated ...
# 701 th segmentation map generated ...
# 702 th segmentation map generated ...
# 703 th segmentation map generated ...
# 704 th segmentation map generated ...
# 705 th segmentation map generated ...
# 706 th segmentation map generated ...
# 707 th segmentation map generated ...
# 708 th segmentation map generated ...
# 709 th segmentation map generated ...
# 710 th segmentation map generated ...
# 711 th segmentation map generated ...
# 712 th segmentation map generated ...
# 713 th segmentation map generated ...
# 714 th segmentation map generated ...
# 715 th segmentation map generated ...
# 716 th segmentation map generated ...
# 717 th segmentation map generated ...
# 718 th segmentation map generated ...
# 719 th segmentation map generated ...
# 720 th segmentation map generated ...
# 721 th segmentation map generated ...
# 722 th segmentation map generated ...
# 723 th segmentation map generated ...
# 724 th segmentation map generated ...
# 725 th segmentation map generated ...
# 726 th segmentation map generated ...
# 727 th segmentation map generated ...
# 728 th segmentation map generated ...
# 729 th segmentation map generated ...
# 730 th segmentation map generated ...
# 731 th segmentation map generated ...
# 732 th segmentation map generated ...
# 733 th segmentation map generated ...
# 734 th segmentation map generated ...
# 735 th segmentation map generated ...
# 736 th segmentation map generated ...
# 737 th segmentation map generated ...
# 738 th segmentation map generated ...
# 739 th segmentation map generated ...
# 740 th segmentation map generated ...
# 741 th segmentation map generated ...
# 742 th segmentation map generated ...
# 743 th segmentation map generated ...
# 744 th segmentation map generated ...
# 745 th segmentation map generated ...
# 746 th segmentation map generated ...
# 747 th segmentation map generated ...
# 748 th segmentation map generated ...
# 749 th segmentation map generated ...
# 750 th segmentation map generated ...
# 751 th segmentation map generated ...
# 752 th segmentation map generated ...
# 753 th segmentation map generated ...
# 754 th segmentation map generated ...
# 755 th segmentation map generated ...
# 756 th segmentation map generated ...
# 757 th segmentation map generated ...
# 758 th segmentation map generated ...
# 759 th segmentation map generated ...
# 760 th segmentation map generated ...
# 761 th segmentation map generated ...
# 762 th segmentation map generated ...
# 763 th segmentation map generated ...
# 764 th segmentation map generated ...
# 765 th segmentation map generated ...
# 766 th segmentation map generated ...
# 767 th segmentation map generated ...
# 768 th segmentation map generated ...
# 769 th segmentation map generated ...
# 770 th segmentation map generated ...
# 771 th segmentation map generated ...
# 772 th segmentation map generated ...
# 773 th segmentation map generated ...
# 774 th segmentation map generated ...
# 775 th segmentation map generated ...
# 776 th segmentation map generated ...
# 777 th segmentation map generated ...
# 778 th segmentation map generated ...
# 779 th segmentation map generated ...
# 780 th segmentation map generated ...
# 781 th segmentation map generated ...
# 782 th segmentation map generated ...
# 783 th segmentation map generated ...
# 784 th segmentation map generated ...
# 785 th segmentation map generated ...
# 786 th segmentation map generated ...
# 787 th segmentation map generated ...
# 788 th segmentation map generated ...
# 789 th segmentation map generated ...
# 790 th segmentation map generated ...
# 791 th segmentation map generated ...
# 792 th segmentation map generated ...
# 793 th segmentation map generated ...
# 794 th segmentation map generated ...
# 795 th segmentation map generated ...
# 796 th segmentation map generated ...
# 797 th segmentation map generated ...
# 798 th segmentation map generated ...
# 799 th segmentation map generated ...
# 800 th segmentation map generated ...
# 400 processd
# 801 th segmentation map generated ...
# 802 th segmentation map generated ...
# 803 th segmentation map generated ...
# 804 th segmentation map generated ...
# 805 th segmentation map generated ...
# 806 th segmentation map generated ...
# 807 th segmentation map generated ...
# 808 th segmentation map generated ...
# 809 th segmentation map generated ...
# 810 th segmentation map generated ...
# 811 th segmentation map generated ...
# 812 th segmentation map generated ...
# 813 th segmentation map generated ...
# 814 th segmentation map generated ...
# 815 th segmentation map generated ...
# 816 th segmentation map generated ...
# 817 th segmentation map generated ...
# 818 th segmentation map generated ...
# 819 th segmentation map generated ...
# 820 th segmentation map generated ...
# 821 th segmentation map generated ...
# 822 th segmentation map generated ...
# 823 th segmentation map generated ...
# 824 th segmentation map generated ...
# 825 th segmentation map generated ...
# 826 th segmentation map generated ...
# 827 th segmentation map generated ...
# 828 th segmentation map generated ...
# 829 th segmentation map generated ...
# 830 th segmentation map generated ...
# 831 th segmentation map generated ...
# 832 th segmentation map generated ...
# 833 th segmentation map generated ...
# 834 th segmentation map generated ...
# 835 th segmentation map generated ...
# 836 th segmentation map generated ...
# 837 th segmentation map generated ...
# 838 th segmentation map generated ...
# 839 th segmentation map generated ...
# 840 th segmentation map generated ...
# 841 th segmentation map generated ...
# 842 th segmentation map generated ...
# 843 th segmentation map generated ...
# 844 th segmentation map generated ...
# 845 th segmentation map generated ...
# 846 th segmentation map generated ...
# 847 th segmentation map generated ...
# 848 th segmentation map generated ...
# 849 th segmentation map generated ...
# 850 th segmentation map generated ...
# 851 th segmentation map generated ...
# 852 th segmentation map generated ...
# 853 th segmentation map generated ...
# 854 th segmentation map generated ...
# 855 th segmentation map generated ...
# 856 th segmentation map generated ...
# 857 th segmentation map generated ...
# 858 th segmentation map generated ...
# 859 th segmentation map generated ...
# 860 th segmentation map generated ...
# 861 th segmentation map generated ...
# 862 th segmentation map generated ...
# 863 th segmentation map generated ...
# 864 th segmentation map generated ...
# 865 th segmentation map generated ...
# 866 th segmentation map generated ...
# 867 th segmentation map generated ...
# 868 th segmentation map generated ...
# 869 th segmentation map generated ...
# 870 th segmentation map generated ...
# 871 th segmentation map generated ...
# 872 th segmentation map generated ...
# 873 th segmentation map generated ...
# 874 th segmentation map generated ...
# 875 th segmentation map generated ...
# 876 th segmentation map generated ...
# 877 th segmentation map generated ...
# 878 th segmentation map generated ...
# 879 th segmentation map generated ...
# 880 th segmentation map generated ...
# 881 th segmentation map generated ...
# 882 th segmentation map generated ...
# 883 th segmentation map generated ...
# 884 th segmentation map generated ...
# 885 th segmentation map generated ...
# 886 th segmentation map generated ...
# 887 th segmentation map generated ...
# 888 th segmentation map generated ...
# 889 th segmentation map generated ...
# 890 th segmentation map generated ...
# 891 th segmentation map generated ...
# 892 th segmentation map generated ...
# 893 th segmentation map generated ...
# 894 th segmentation map generated ...
# 895 th segmentation map generated ...
# 896 th segmentation map generated ...
# 897 th segmentation map generated ...
# 898 th segmentation map generated ...
# 899 th segmentation map generated ...
# 900 th segmentation map generated ...
# 901 th segmentation map generated ...
# 902 th segmentation map generated ...
# 903 th segmentation map generated ...
# 904 th segmentation map generated ...
# 905 th segmentation map generated ...
# 906 th segmentation map generated ...
# 907 th segmentation map generated ...
# 908 th segmentation map generated ...
# 909 th segmentation map generated ...
# 910 th segmentation map generated ...
# 911 th segmentation map generated ...
# 912 th segmentation map generated ...
# 913 th segmentation map generated ...
# 914 th segmentation map generated ...
# 915 th segmentation map generated ...
# 916 th segmentation map generated ...
# 917 th segmentation map generated ...
# 918 th segmentation map generated ...
# 919 th segmentation map generated ...
# 920 th segmentation map generated ...
# 921 th segmentation map generated ...
# 922 th segmentation map generated ...
# 923 th segmentation map generated ...
# 924 th segmentation map generated ...
# 925 th segmentation map generated ...
# 926 th segmentation map generated ...
# 927 th segmentation map generated ...
# 928 th segmentation map generated ...
# 929 th segmentation map generated ...
# 930 th segmentation map generated ...
# 931 th segmentation map generated ...
# 932 th segmentation map generated ...
# 933 th segmentation map generated ...
# 934 th segmentation map generated ...
# 935 th segmentation map generated ...
# 936 th segmentation map generated ...
# 937 th segmentation map generated ...
# 938 th segmentation map generated ...
# 939 th segmentation map generated ...
# 940 th segmentation map generated ...
# 941 th segmentation map generated ...
# 942 th segmentation map generated ...
# 943 th segmentation map generated ...
# 944 th segmentation map generated ...
# 945 th segmentation map generated ...
# 946 th segmentation map generated ...
# 947 th segmentation map generated ...
# 948 th segmentation map generated ...
# 949 th segmentation map generated ...
# 950 th segmentation map generated ...
# 951 th segmentation map generated ...
# 952 th segmentation map generated ...
# 953 th segmentation map generated ...
# 954 th segmentation map generated ...
# 955 th segmentation map generated ...
# 956 th segmentation map generated ...
# 957 th segmentation map generated ...
# 958 th segmentation map generated ...
# 959 th segmentation map generated ...
# 960 th segmentation map generated ...
# 961 th segmentation map generated ...
# 962 th segmentation map generated ...
# 963 th segmentation map generated ...
# 964 th segmentation map generated ...
# 965 th segmentation map generated ...
# 966 th segmentation map generated ...
# 967 th segmentation map generated ...
# 968 th segmentation map generated ...
# 969 th segmentation map generated ...
# 970 th segmentation map generated ...
# 971 th segmentation map generated ...
# 972 th segmentation map generated ...
# 973 th segmentation map generated ...
# 974 th segmentation map generated ...
# 975 th segmentation map generated ...
# 976 th segmentation map generated ...
# 977 th segmentation map generated ...
# 978 th segmentation map generated ...
# 979 th segmentation map generated ...
# 980 th segmentation map generated ...
# 981 th segmentation map generated ...
# 982 th segmentation map generated ...
# 983 th segmentation map generated ...
# 984 th segmentation map generated ...
# 985 th segmentation map generated ...
# 986 th segmentation map generated ...
# 987 th segmentation map generated ...
# 988 th segmentation map generated ...
# 989 th segmentation map generated ...
# 990 th segmentation map generated ...
# 991 th segmentation map generated ...
# 992 th segmentation map generated ...
# 993 th segmentation map generated ...
# 994 th segmentation map generated ...
# 995 th segmentation map generated ...
# 996 th segmentation map generated ...
# 997 th segmentation map generated ...
# 998 th segmentation map generated ...
# 999 th segmentation map generated ...
# 1000 th segmentation map generated ...
# 500 processd
# 1001 th segmentation map generated ...
# 1002 th segmentation map generated ...
# 1003 th segmentation map generated ...
# 1004 th segmentation map generated ...
# 1005 th segmentation map generated ...
# 1006 th segmentation map generated ...
# 1007 th segmentation map generated ...
# 1008 th segmentation map generated ...
# 1009 th segmentation map generated ...
# 1010 th segmentation map generated ...
# 1011 th segmentation map generated ...
# 1012 th segmentation map generated ...
# 1013 th segmentation map generated ...
# 1014 th segmentation map generated ...
# 1015 th segmentation map generated ...
# 1016 th segmentation map generated ...
# 1017 th segmentation map generated ...
# 1018 th segmentation map generated ...
# 1019 th segmentation map generated ...
# 1020 th segmentation map generated ...
# 1021 th segmentation map generated ...
# 1022 th segmentation map generated ...
# 1023 th segmentation map generated ...
# 1024 th segmentation map generated ...
# 1025 th segmentation map generated ...
# 1026 th segmentation map generated ...
# 1027 th segmentation map generated ...
# 1028 th segmentation map generated ...
# 1029 th segmentation map generated ...
# 1030 th segmentation map generated ...
# 1031 th segmentation map generated ...
# 1032 th segmentation map generated ...
# 1033 th segmentation map generated ...
# 1034 th segmentation map generated ...
# 1035 th segmentation map generated ...
# 1036 th segmentation map generated ...
# 1037 th segmentation map generated ...
# 1038 th segmentation map generated ...
# 1039 th segmentation map generated ...
# 1040 th segmentation map generated ...
# 1041 th segmentation map generated ...
# 1042 th segmentation map generated ...
# 1043 th segmentation map generated ...
# 1044 th segmentation map generated ...
# 1045 th segmentation map generated ...
# 1046 th segmentation map generated ...
# 1047 th segmentation map generated ...
# 1048 th segmentation map generated ...
# 1049 th segmentation map generated ...
# 1050 th segmentation map generated ...
# 1051 th segmentation map generated ...
# 1052 th segmentation map generated ...
# 1053 th segmentation map generated ...
# 1054 th segmentation map generated ...
# 1055 th segmentation map generated ...
# 1056 th segmentation map generated ...
# 1057 th segmentation map generated ...
# 1058 th segmentation map generated ...
# 1059 th segmentation map generated ...
# 1060 th segmentation map generated ...
# 1061 th segmentation map generated ...
# 1062 th segmentation map generated ...
# 1063 th segmentation map generated ...
# 1064 th segmentation map generated ...
# 1065 th segmentation map generated ...
# 1066 th segmentation map generated ...
# 1067 th segmentation map generated ...
# 1068 th segmentation map generated ...
# 1069 th segmentation map generated ...
# 1070 th segmentation map generated ...
# 1071 th segmentation map generated ...
# 1072 th segmentation map generated ...
# 1073 th segmentation map generated ...
# 1074 th segmentation map generated ...
# 1075 th segmentation map generated ...
# 1076 th segmentation map generated ...
# 1077 th segmentation map generated ...
# 1078 th segmentation map generated ...
# 1079 th segmentation map generated ...
# 1080 th segmentation map generated ...
# 1081 th segmentation map generated ...
# 1082 th segmentation map generated ...
# 1083 th segmentation map generated ...
# 1084 th segmentation map generated ...
# 1085 th segmentation map generated ...
# 1086 th segmentation map generated ...
# 1087 th segmentation map generated ...
# 1088 th segmentation map generated ...
# 1089 th segmentation map generated ...
# 1090 th segmentation map generated ...
# 1091 th segmentation map generated ...
# 1092 th segmentation map generated ...
# 1093 th segmentation map generated ...
# 1094 th segmentation map generated ...
# 1095 th segmentation map generated ...
# 1096 th segmentation map generated ...
# 1097 th segmentation map generated ...
# 1098 th segmentation map generated ...
# 1099 th segmentation map generated ...
# 1100 th segmentation map generated ...
# 1101 th segmentation map generated ...
# 1102 th segmentation map generated ...
# 1103 th segmentation map generated ...
# 1104 th segmentation map generated ...
# 1105 th segmentation map generated ...
# 1106 th segmentation map generated ...
# 1107 th segmentation map generated ...
# 1108 th segmentation map generated ...
# 1109 th segmentation map generated ...
# 1110 th segmentation map generated ...
# 1111 th segmentation map generated ...
# 1112 th segmentation map generated ...
# 1113 th segmentation map generated ...
# 1114 th segmentation map generated ...
# 1115 th segmentation map generated ...
# 1116 th segmentation map generated ...
# 1117 th segmentation map generated ...
# 1118 th segmentation map generated ...
# 1119 th segmentation map generated ...
# 1120 th segmentation map generated ...
# 1121 th segmentation map generated ...
# 1122 th segmentation map generated ...
# 1123 th segmentation map generated ...
# 1124 th segmentation map generated ...
# 1125 th segmentation map generated ...
# 1126 th segmentation map generated ...
# 1127 th segmentation map generated ...
# 1128 th segmentation map generated ...
# 1129 th segmentation map generated ...
# 1130 th segmentation map generated ...
# 1131 th segmentation map generated ...
# 1132 th segmentation map generated ...
# 1133 th segmentation map generated ...
# 1134 th segmentation map generated ...
# 1135 th segmentation map generated ...
# 1136 th segmentation map generated ...
# 1137 th segmentation map generated ...
# 1138 th segmentation map generated ...
# 1139 th segmentation map generated ...
# 1140 th segmentation map generated ...
# 1141 th segmentation map generated ...
# 1142 th segmentation map generated ...
# 1143 th segmentation map generated ...
# 1144 th segmentation map generated ...
# 1145 th segmentation map generated ...
# 1146 th segmentation map generated ...
# 1147 th segmentation map generated ...
# 1148 th segmentation map generated ...
# 1149 th segmentation map generated ...
# 1150 th segmentation map generated ...
# 1151 th segmentation map generated ...
# 1152 th segmentation map generated ...
# 1153 th segmentation map generated ...
# 1154 th segmentation map generated ...
# 1155 th segmentation map generated ...
# 1156 th segmentation map generated ...
# 1157 th segmentation map generated ...
# 1158 th segmentation map generated ...
# 1159 th segmentation map generated ...
# 1160 th segmentation map generated ...
# 1161 th segmentation map generated ...
# 1162 th segmentation map generated ...
# 1163 th segmentation map generated ...
# 1164 th segmentation map generated ...
# 1165 th segmentation map generated ...
# 1166 th segmentation map generated ...
# 1167 th segmentation map generated ...
# 1168 th segmentation map generated ...
# 1169 th segmentation map generated ...
# 1170 th segmentation map generated ...
# 1171 th segmentation map generated ...
# 1172 th segmentation map generated ...
# 1173 th segmentation map generated ...
# 1174 th segmentation map generated ...
# 1175 th segmentation map generated ...
# 1176 th segmentation map generated ...
# 1177 th segmentation map generated ...
# 1178 th segmentation map generated ...
# 1179 th segmentation map generated ...
# 1180 th segmentation map generated ...
# 1181 th segmentation map generated ...
# 1182 th segmentation map generated ...
# 1183 th segmentation map generated ...
# 1184 th segmentation map generated ...
# 1185 th segmentation map generated ...
# 1186 th segmentation map generated ...
# 1187 th segmentation map generated ...
# 1188 th segmentation map generated ...
# 1189 th segmentation map generated ...
# 1190 th segmentation map generated ...
# 1191 th segmentation map generated ...
# 1192 th segmentation map generated ...
# 1193 th segmentation map generated ...
# 1194 th segmentation map generated ...
# 1195 th segmentation map generated ...
# 1196 th segmentation map generated ...
# 1197 th segmentation map generated ...
# 1198 th segmentation map generated ...
# 1199 th segmentation map generated ...
# 1200 th segmentation map generated ...
# 600 processd
# 1201 th segmentation map generated ...
# 1202 th segmentation map generated ...
# 1203 th segmentation map generated ...
# 1204 th segmentation map generated ...
# 1205 th segmentation map generated ...
# 1206 th segmentation map generated ...
# 1207 th segmentation map generated ...
# 1208 th segmentation map generated ...
# 1209 th segmentation map generated ...
# 1210 th segmentation map generated ...
# 1211 th segmentation map generated ...
# 1212 th segmentation map generated ...
# 1213 th segmentation map generated ...
# 1214 th segmentation map generated ...
# 1215 th segmentation map generated ...
# 1216 th segmentation map generated ...
# 1217 th segmentation map generated ...
# 1218 th segmentation map generated ...
# 1219 th segmentation map generated ...
# 1220 th segmentation map generated ...
# 1221 th segmentation map generated ...
# 1222 th segmentation map generated ...
# 1223 th segmentation map generated ...
# 1224 th segmentation map generated ...
# 1225 th segmentation map generated ...
# 1226 th segmentation map generated ...
# 1227 th segmentation map generated ...
# 1228 th segmentation map generated ...
# 1229 th segmentation map generated ...
# 1230 th segmentation map generated ...
# 1231 th segmentation map generated ...
# 1232 th segmentation map generated ...
# 1233 th segmentation map generated ...
# 1234 th segmentation map generated ...
# 1235 th segmentation map generated ...
# 1236 th segmentation map generated ...
# 1237 th segmentation map generated ...
# 1238 th segmentation map generated ...
# 1239 th segmentation map generated ...
# 1240 th segmentation map generated ...
# 1241 th segmentation map generated ...
# 1242 th segmentation map generated ...
# 1243 th segmentation map generated ...
# 1244 th segmentation map generated ...
# 1245 th segmentation map generated ...
# 1246 th segmentation map generated ...
# 1247 th segmentation map generated ...
# 1248 th segmentation map generated ...
# 1249 th segmentation map generated ...
# 1250 th segmentation map generated ...
# 1251 th segmentation map generated ...
# 1252 th segmentation map generated ...
# 1253 th segmentation map generated ...
# 1254 th segmentation map generated ...
# 1255 th segmentation map generated ...
# 1256 th segmentation map generated ...
# 1257 th segmentation map generated ...
# 1258 th segmentation map generated ...
# 1259 th segmentation map generated ...
# 1260 th segmentation map generated ...
# 1261 th segmentation map generated ...
# 1262 th segmentation map generated ...
# 1263 th segmentation map generated ...
# 1264 th segmentation map generated ...
# 1265 th segmentation map generated ...
# 1266 th segmentation map generated ...
# 1267 th segmentation map generated ...
# 1268 th segmentation map generated ...
# 1269 th segmentation map generated ...
# 1270 th segmentation map generated ...
# 1271 th segmentation map generated ...
# 1272 th segmentation map generated ...
# 1273 th segmentation map generated ...
# 1274 th segmentation map generated ...
# 1275 th segmentation map generated ...
# 1276 th segmentation map generated ...
# 1277 th segmentation map generated ...
# 1278 th segmentation map generated ...
# 1279 th segmentation map generated ...
# 1280 th segmentation map generated ...
# 1281 th segmentation map generated ...
# 1282 th segmentation map generated ...
# 1283 th segmentation map generated ...
# 1284 th segmentation map generated ...
# 1285 th segmentation map generated ...
# 1286 th segmentation map generated ...
# 1287 th segmentation map generated ...
# 1288 th segmentation map generated ...
# 1289 th segmentation map generated ...
# 1290 th segmentation map generated ...
# 1291 th segmentation map generated ...
# 1292 th segmentation map generated ...
# 1293 th segmentation map generated ...
# 1294 th segmentation map generated ...
# 1295 th segmentation map generated ...
# 1296 th segmentation map generated ...
# 1297 th segmentation map generated ...
# 1298 th segmentation map generated ...
# 1299 th segmentation map generated ...
# 1300 th segmentation map generated ...
# 1301 th segmentation map generated ...
# 1302 th segmentation map generated ...
# 1303 th segmentation map generated ...
# 1304 th segmentation map generated ...
# 1305 th segmentation map generated ...
# 1306 th segmentation map generated ...
# 1307 th segmentation map generated ...
# 1308 th segmentation map generated ...
# 1309 th segmentation map generated ...
# 1310 th segmentation map generated ...
# 1311 th segmentation map generated ...
# 1312 th segmentation map generated ...
# 1313 th segmentation map generated ...
# 1314 th segmentation map generated ...
# 1315 th segmentation map generated ...
# 1316 th segmentation map generated ...
# 1317 th segmentation map generated ...
# 1318 th segmentation map generated ...
# 1319 th segmentation map generated ...
# 1320 th segmentation map generated ...
# 1321 th segmentation map generated ...
# 1322 th segmentation map generated ...
# 1323 th segmentation map generated ...
# 1324 th segmentation map generated ...
# 1325 th segmentation map generated ...
# 1326 th segmentation map generated ...
# 1327 th segmentation map generated ...
# 1328 th segmentation map generated ...
# 1329 th segmentation map generated ...
# 1330 th segmentation map generated ...
# 1331 th segmentation map generated ...
# 1332 th segmentation map generated ...
# 1333 th segmentation map generated ...
# 1334 th segmentation map generated ...
# 1335 th segmentation map generated ...
# 1336 th segmentation map generated ...
# 1337 th segmentation map generated ...
# 1338 th segmentation map generated ...
# 1339 th segmentation map generated ...
# 1340 th segmentation map generated ...
# 1341 th segmentation map generated ...
# 1342 th segmentation map generated ...
# 1343 th segmentation map generated ...
# 1344 th segmentation map generated ...
# 1345 th segmentation map generated ...
# 1346 th segmentation map generated ...
# 1347 th segmentation map generated ...
# 1348 th segmentation map generated ...
# 1349 th segmentation map generated ...
# 1350 th segmentation map generated ...
# 1351 th segmentation map generated ...
# 1352 th segmentation map generated ...
# 1353 th segmentation map generated ...
# 1354 th segmentation map generated ...
# 1355 th segmentation map generated ...
# 1356 th segmentation map generated ...
# 1357 th segmentation map generated ...
# 1358 th segmentation map generated ...
# 1359 th segmentation map generated ...
# 1360 th segmentation map generated ...
# 1361 th segmentation map generated ...
# 1362 th segmentation map generated ...
# 1363 th segmentation map generated ...
# 1364 th segmentation map generated ...
# 1365 th segmentation map generated ...
# 1366 th segmentation map generated ...
# 1367 th segmentation map generated ...
# 1368 th segmentation map generated ...
# 1369 th segmentation map generated ...
# 1370 th segmentation map generated ...
# 1371 th segmentation map generated ...
# 1372 th segmentation map generated ...
# 1373 th segmentation map generated ...
# 1374 th segmentation map generated ...
# 1375 th segmentation map generated ...
# 1376 th segmentation map generated ...
# 1377 th segmentation map generated ...
# 1378 th segmentation map generated ...
# 1379 th segmentation map generated ...
# 1380 th segmentation map generated ...
# 1381 th segmentation map generated ...
# 1382 th segmentation map generated ...
# 1383 th segmentation map generated ...
# 1384 th segmentation map generated ...
# 1385 th segmentation map generated ...
# 1386 th segmentation map generated ...
# 1387 th segmentation map generated ...
# 1388 th segmentation map generated ...
# 1389 th segmentation map generated ...
# 1390 th segmentation map generated ...
# 1391 th segmentation map generated ...
# 1392 th segmentation map generated ...
# 1393 th segmentation map generated ...
# 1394 th segmentation map generated ...
# 1395 th segmentation map generated ...
# 1396 th segmentation map generated ...
# 1397 th segmentation map generated ...
# 1398 th segmentation map generated ...
# 1399 th segmentation map generated ...
# 1400 th segmentation map generated ...
# 700 processd
# 1401 th segmentation map generated ...
# 1402 th segmentation map generated ...
# 1403 th segmentation map generated ...
# 1404 th segmentation map generated ...
# 1405 th segmentation map generated ...
# 1406 th segmentation map generated ...
# 1407 th segmentation map generated ...
# 1408 th segmentation map generated ...
# 1409 th segmentation map generated ...
# 1410 th segmentation map generated ...
# 1411 th segmentation map generated ...
# 1412 th segmentation map generated ...
# 1413 th segmentation map generated ...
# 1414 th segmentation map generated ...
# 1415 th segmentation map generated ...
# 1416 th segmentation map generated ...
# 1417 th segmentation map generated ...
# 1418 th segmentation map generated ...
# 1419 th segmentation map generated ...
# 1420 th segmentation map generated ...
# 1421 th segmentation map generated ...
# 1422 th segmentation map generated ...
# 1423 th segmentation map generated ...
# 1424 th segmentation map generated ...
# 1425 th segmentation map generated ...
# 1426 th segmentation map generated ...
# 1427 th segmentation map generated ...
# 1428 th segmentation map generated ...
# 1429 th segmentation map generated ...
# 1430 th segmentation map generated ...
# 1431 th segmentation map generated ...
# 1432 th segmentation map generated ...
# 1433 th segmentation map generated ...
# 1434 th segmentation map generated ...
# 1435 th segmentation map generated ...
# 1436 th segmentation map generated ...
# 1437 th segmentation map generated ...
# 1438 th segmentation map generated ...
# 1439 th segmentation map generated ...
# 1440 th segmentation map generated ...
# 1441 th segmentation map generated ...
# 1442 th segmentation map generated ...
# 1443 th segmentation map generated ...
# 1444 th segmentation map generated ...
# 1445 th segmentation map generated ...
# 1446 th segmentation map generated ...
# 1447 th segmentation map generated ...
# 1448 th segmentation map generated ...
# 1449 th segmentation map generated ...
# 1450 th segmentation map generated ...
# 1451 th segmentation map generated ...
# 1452 th segmentation map generated ...
# 1453 th segmentation map generated ...
# 1454 th segmentation map generated ...
# 1455 th segmentation map generated ...
# 1456 th segmentation map generated ...
# 1457 th segmentation map generated ...
# 1458 th segmentation map generated ...
# 1459 th segmentation map generated ...
# 1460 th segmentation map generated ...
# 1461 th segmentation map generated ...
# 1462 th segmentation map generated ...
# 1463 th segmentation map generated ...
# 1464 th segmentation map generated ...
# 1465 th segmentation map generated ...
# 1466 th segmentation map generated ...
# 1467 th segmentation map generated ...
# 1468 th segmentation map generated ...
# 1469 th segmentation map generated ...
# 1470 th segmentation map generated ...
# 1471 th segmentation map generated ...
# 1472 th segmentation map generated ...
# 1473 th segmentation map generated ...
# 1474 th segmentation map generated ...
# 1475 th segmentation map generated ...
# 1476 th segmentation map generated ...
# 1477 th segmentation map generated ...
# 1478 th segmentation map generated ...
# 1479 th segmentation map generated ...
# 1480 th segmentation map generated ...
# 1481 th segmentation map generated ...
# 1482 th segmentation map generated ...
# 1483 th segmentation map generated ...
# 1484 th segmentation map generated ...
# 1485 th segmentation map generated ...
# 1486 th segmentation map generated ...
# 1487 th segmentation map generated ...
# 1488 th segmentation map generated ...
# 1489 th segmentation map generated ...
# 1490 th segmentation map generated ...
# 1491 th segmentation map generated ...
# 1492 th segmentation map generated ...
# 1493 th segmentation map generated ...
# 1494 th segmentation map generated ...
# 1495 th segmentation map generated ...
# 1496 th segmentation map generated ...
# 1497 th segmentation map generated ...
# 1498 th segmentation map generated ...
# 1499 th segmentation map generated ...
# 1500 th segmentation map generated ...
# 1501 th segmentation map generated ...
# 1502 th segmentation map generated ...
# 1503 th segmentation map generated ...
# 1504 th segmentation map generated ...
# 1505 th segmentation map generated ...
# 1506 th segmentation map generated ...
# 1507 th segmentation map generated ...
# 1508 th segmentation map generated ...
# 1509 th segmentation map generated ...
# 1510 th segmentation map generated ...
# 1511 th segmentation map generated ...
# 1512 th segmentation map generated ...
# 1513 th segmentation map generated ...
# 1514 th segmentation map generated ...
# 1515 th segmentation map generated ...
# 1516 th segmentation map generated ...
# 1517 th segmentation map generated ...
# 1518 th segmentation map generated ...
# 1519 th segmentation map generated ...
# 1520 th segmentation map generated ...
# 1521 th segmentation map generated ...
# 1522 th segmentation map generated ...
# 1523 th segmentation map generated ...
# 1524 th segmentation map generated ...
# 1525 th segmentation map generated ...
